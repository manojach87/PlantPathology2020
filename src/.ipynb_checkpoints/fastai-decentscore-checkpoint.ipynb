# %% [markdown]
# This will autoload the new/updated packages

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai.vision import *
from fastai.metrics import error_rate

# %% [markdown]
# This is the batch size

# %%
bs = 250
# bs = 16   # uncomment this line if you run out of memory even after clicking Kernel->Restart

# %% [markdown]
# Function to read from JSON file

# %%
def readJSONFile(path):
    import json
    with open(path) as f:
        data = json.load(f)
    return data

# %%
#dataPath=Path('/home/manoj/Documents/data/data/')
dataPath=Path('c:/Users/manoj/PycharmProjects/data/PlantPathology2020/')
dataPath.ls()
# Out:
# [WindowsPath('c:/Users/manoj/PycharmProjects/data/PlantPathology2020/images'),
#  WindowsPath('c:/Users/manoj/PycharmProjects/data/PlantPathology2020/sample_submission.csv'),
#  WindowsPath('c:/Users/manoj/PycharmProjects/data/PlantPathology2020/test.csv'),
#  WindowsPath('c:/Users/manoj/PycharmProjects/data/PlantPathology2020/train.csv')]

# %%
testImageList

# %%
#jsonFilePath='/home/manoj/Documents/data/data/iwildcam-2020/iwildcam2020_train_annotations.json'
jsonFilePath=dataPath/'iwildcam2020_train_annotations.json'

# %%
data = readJSONFile(jsonFilePath)

annotations = data["annotations"]
images=data["images"]
categories = data["categories"]
info = data["info"]

# Convert to Data frame

annotations = pd.DataFrame.from_dict(annotations)
images = pd.DataFrame.from_dict(images)
categories = pd.DataFrame.from_dict(categories)


#Remove data from memory
del data

#Create column image_id to use for merging the two data frames
images["image_id"]  = images["id"]

# Merge annotations and images on image_id

trainDf1 = (pd.merge(annotations, images, on='image_id'))
#Remove Unnecessary fields
trainDf1.drop(["id_y","id_x"], axis = 1, inplace=True)

#print(trainDf1.columns)

trainDf1 = pd.merge(trainDf1, categories.rename(columns={"id":"category_id"}), on="category_id" )
# Unset annotations and images dataframe as they are no longer needed
del annotations
del images

# %%
categories[categories["id"]==115 ]
# Out:
#     count   id               name
# 65   3426  115  madoqua guentheri

# %%
categories
# Out:
#      count   id                     name
# 0    78981    0                    empty
# 1     6355    2           tayassu pecari
# 2     5833    3      dasyprocta punctata
# 3      619    4           cuniculus paca
# 4     4453    6            puma concolor
# ..     ...  ...                      ...
# 262      6  671  thryonomys swinderianus
# 263      3  672          ploceus alienus
# 264      3  673       ploceus baglafecht
# 265      2  674    poecilogale albinucha
# 266      6  675     anomalurus derbianus
#
# [267 rows x 3 columns]

# %%
trainDf1[["name","category_id"]]
# Out:
#                   name  category_id
# 0          canis lupus           73
# 1          canis lupus           73
# 2          canis lupus           73
# 3          canis lupus           73
# 4          canis lupus           73
# ...                ...          ...
# 217954  mazama  temama          571
# 217955  mazama  temama          571
# 217956  mazama  temama          571
# 217957  mazama  temama          571
# 217958  mazama  temama          571
#
# [217959 rows x 2 columns]

# %%
df=trainDf1[["file_name","category_id"]]
df=df.rename(columns={"file_name":"name","category_id":"label"})

#df=trainDf1[["file_name","name"]]
#df=df.rename(columns={"file_name":"name","name":"label"})

# %%
df
# Out:
#                                             name  label
# 0       96b00332-21bc-11ea-a13a-137349068a90.jpg     73
# 1       973073b4-21bc-11ea-a13a-137349068a90.jpg     73
# 2       89588844-21bc-11ea-a13a-137349068a90.jpg     73
# 3       87dc5806-21bc-11ea-a13a-137349068a90.jpg     73
# 4       96960680-21bc-11ea-a13a-137349068a90.jpg     73
# ...                                          ...    ...
# 217954  8b102e26-21bc-11ea-a13a-137349068a90.jpg    571
# 217955  97e76998-21bc-11ea-a13a-137349068a90.jpg    571
# 217956  8ee5c9fc-21bc-11ea-a13a-137349068a90.jpg    571
# 217957  97f875da-21bc-11ea-a13a-137349068a90.jpg    571
# 217958  8f2e6216-21bc-11ea-a13a-137349068a90.jpg    571
#
# [217959 rows x 2 columns]

# %%
minSamples=1000
duplicateDf=pd.DataFrame()

for label in df["label"].unique():
    length=0
    
    x=min
    y=len(df[df["label"]==label])
    multiplier=1
    if(y<minSamples):
        multiplier=int(minSamples/y)
        y=y*multiplier
    #length=y
    #print("{} {} {}".format(y, multiplier, length))
    duplicateDf=duplicateDf.append([df[df["label"]==label]]*multiplier,ignore_index=True)

df=duplicateDf

# %%
df
# Out:
#                                             name  label
# 0       96b00332-21bc-11ea-a13a-137349068a90.jpg     73
# 1       973073b4-21bc-11ea-a13a-137349068a90.jpg     73
# 2       89588844-21bc-11ea-a13a-137349068a90.jpg     73
# 3       87dc5806-21bc-11ea-a13a-137349068a90.jpg     73
# 4       96960680-21bc-11ea-a13a-137349068a90.jpg     73
# ...                                          ...    ...
# 374160  8b102e26-21bc-11ea-a13a-137349068a90.jpg    571
# 374161  97e76998-21bc-11ea-a13a-137349068a90.jpg    571
# 374162  8ee5c9fc-21bc-11ea-a13a-137349068a90.jpg    571
# 374163  97f875da-21bc-11ea-a13a-137349068a90.jpg    571
# 374164  8f2e6216-21bc-11ea-a13a-137349068a90.jpg    571
#
# [374165 rows x 2 columns]

# %%
tfms = get_transforms(do_flip=False)

filePath=str(dataPath/"train/400X400")

import os
print(os.getcwd())
print(filePath)
df
# Out:
# /home/manoj/Documents/GitHub/IWildCam2020/src
# /home/manoj/Documents/data/data/iwildcam-2020/train/400X400
#                                             name  label
# 0       96b00332-21bc-11ea-a13a-137349068a90.jpg     73
# 1       973073b4-21bc-11ea-a13a-137349068a90.jpg     73
# 2       89588844-21bc-11ea-a13a-137349068a90.jpg     73
# 3       87dc5806-21bc-11ea-a13a-137349068a90.jpg     73
# 4       96960680-21bc-11ea-a13a-137349068a90.jpg     73
# ...                                          ...    ...
# 374160  8b102e26-21bc-11ea-a13a-137349068a90.jpg    571
# 374161  97e76998-21bc-11ea-a13a-137349068a90.jpg    571
# 374162  8ee5c9fc-21bc-11ea-a13a-137349068a90.jpg    571
# 374163  97f875da-21bc-11ea-a13a-137349068a90.jpg    571
# 374164  8f2e6216-21bc-11ea-a13a-137349068a90.jpg    571
#
# [374165 rows x 2 columns]

# %%
# This os th eold one with 200x200 px'''
i=0
while 1:
    try:
        np.random.seed(i)
        data=ImageDataBunch.from_df(filePath, df, ds_tfms=tfms, size=224, bs=100)
    except:
        i+=1
        if(i%100==0):
            print(str(i) + " did not work")
        continue
    else: 
        print('Seed '+str(i)+' works')
        break
    break
'''
# Out:
#   File "<ipython-input-67-acbacf65b7f0>", line 16
#     '''
#            ^
# SyntaxError: EOF while scanning triple-quoted string literal

# %%
np.random.seed(25)
#data = ImageDataBunch.from_df("/home/manoj/Documents/data/data/iwildcam-2020/train/28X28",df, 
data = ImageDataBunch.from_df(filePath
                              , pd.DataFrame(df)
                              , ds_tfms=tfms
                              , size=224
                              , valid_pct=.2
                              , bs=bs)

# %%
categories[categories["id"].isin([257, 229, 420, 306, 296, 402, 408, 420, 412])]
# Out:
#      count   id                    name
# 106      1  229      nothocrax urumutum
# 120      2  257       otocyon megalotis
# 134      1  296        varanus salvator
# 139      1  306  polyplectron chalcurum
# 202      1  402             tragulus sp
# 208      1  408   leiothrix argentauris
# 212      2  412         erithacus cyane
# 220      1  420    callosciurus notatus

# %%
#doc(ImageDataBunch.from_df)

# %%
data.show_batch(rows=3, figsize=(15,15))

# %%
print(data.classes)
len(data.classes),data.c
# Out:
# [0, 2, 3, 4, 6, 7, 8, 9, 10, 12, 13, 14, 15, 16, 20, 24, 25, 26, 32, 44, 50, 62, 67, 70, 71, 72, 73, 74, 77, 78, 79, 80, 83, 86, 89, 90, 91, 92, 94, 96, 97, 98, 99, 100, 101, 102, 103, 104, 106, 108, 110, 111, 112, 113, 114, 115, 116, 118, 119, 120, 121, 122, 123, 124, 127, 129, 130, 133, 134, 137, 139, 141, 142, 144, 145, 147, 150, 152, 153, 154, 156, 159, 161, 162, 163, 166, 167, 170, 175, 177, 198, 221, 227, 229, 230, 233, 234, 235, 240, 242, 243, 245, 250, 251, 252, 253, 256, 257, 258, 259, 262, 265, 267, 268, 273, 286, 290, 291, 292, 294, 296, 299, 300, 301, 302, 306, 307, 309, 310, 315, 316, 317, 318, 319, 320, 321, 322, 323, 324, 325, 326, 327, 328, 330, 332, 333, 334, 335, 336, 337, 338, 339, 340, 341, 342, 344, 345, 346, 347, 348, 349, 350, 352, 353, 354, 355, 356, 357, 370, 371, 372, 374, 375, 376, 377, 378, 379, 380, 382, 384, 385, 389, 390, 391, 402, 404, 405, 406, 407, 408, 409, 410, 412, 413, 414, 415, 416, 417, 418, 419, 420, 422, 454, 558, 559, 561, 562, 563, 564, 565, 566, 567, 568, 569, 570, 571]
# (216, 216)

# %%
learn = cnn_learner(data, models.resnet34, metrics=error_rate)
#learn = cnn_learner(data, models.resnet50, metrics=error_rate)

# %%
learn.model
# Out:
# Sequential(
#   (0): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (2): ReLU(inplace=True)
#     (3): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (5): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (7): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (1): Sequential(
#     (0): AdaptiveConcatPool2d(
#       (ap): AdaptiveAvgPool2d(output_size=1)
#       (mp): AdaptiveMaxPool2d(output_size=1)
#     )
#     (1): Flatten()
#     (2): BatchNorm1d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): Dropout(p=0.25, inplace=False)
#     (4): Linear(in_features=1024, out_features=512, bias=True)
#     (5): ReLU(inplace=True)
#     (6): BatchNorm1d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=512, out_features=216, bias=True)
#   )
# )

# %%
learn.fit_one_cycle(1)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.893470</td>
#       <td>0.630730</td>
#       <td>0.175230</td>
#       <td>08:02</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(3)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.811449</td>
#       <td>1.176055</td>
#       <td>0.307618</td>
#       <td>01:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.196076</td>
#       <td>0.845301</td>
#       <td>0.237101</td>
#       <td>01:53</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.055709</td>
#       <td>0.775786</td>
#       <td>0.216776</td>
#       <td>01:53</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Training Loss is greater than validation loss. Something isn't right

# %%
import torch
torch.cuda.empty_cache()

# %%
learn.recorder.plot_losses()

# %%
learn.save('stage-1.50.040100')

# %%
interp = ClassificationInterpretation.from_learner(learn)

losses,idxs = interp.top_losses()

len(data.valid_ds)==len(losses)==len(idxs)
# Out:
# True

# %%
interp.plot_top_losses(9, figsize=(15,11))

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-22-d745160313a7> in <module>
# ----> 1 interp.plot_confusion_matrix(figsize=(12,12), dpi=60)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/train.py in plot_confusion_matrix(self, normalize, title, cmap, slice_size, norm_dec, plot_txt, return_fig, **kwargs)
#     193         "Plot the confusion matrix, with `title` and using `cmap`."
#     194         # This function is mainly copied from the sklearn docs
# --> 195         cm = self.confusion_matrix(slice_size=slice_size)
#     196         if normalize: cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
#     197         fig = plt.figure(**kwargs)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/train.py in confusion_matrix(self, slice_size)
#     185             for i in range(0, self.y_true.shape[0], slice_size):
#     186                 cm_slice = ((self.pred_class[i:i+slice_size]==x[:,None])
# --> 187                             & (self.y_true[i:i+slice_size]==x[:,None,None])).sum(2)
#     188                 torch.add(cm, cm_slice, out=cm)
#     189         return to_np(cm)
#
# KeyboardInterrupt:

# %%
interp.most_confused(min_val=2)
# Out:
# [(374, 372, 316),
#  (372, 374, 280),
#  (79, 0, 189),
#  (24, 10, 148),
#  (115, 0, 136),
#  (6, 10, 132),
#  (558, 372, 132),
#  (374, 3, 130),
#  (103, 96, 124),
#  (90, 96, 111),
#  (371, 372, 110),
#  (299, 0, 100),
#  (371, 10, 100),
#  (144, 0, 95),
#  (372, 3, 94),
#  (376, 10, 93),
#  (3, 372, 91),
#  (375, 10, 90),
#  (6, 372, 88),
#  (96, 0, 88),
#  (372, 558, 87),
#  (24, 372, 86),
#  (291, 0, 86),
#  (3, 374, 83),
#  (380, 3, 79),
#  (10, 375, 77),
#  (374, 558, 76),
#  (243, 10, 75),
#  (0, 372, 74),
#  (380, 372, 74),
#  (371, 3, 71),
#  (137, 0, 69),
#  (240, 372, 68),
#  (0, 96, 66),
#  (6, 374, 65),
#  (290, 0, 65),
#  (10, 24, 64),
#  (71, 96, 64),
#  (115, 96, 64),
#  (315, 317, 63),
#  (309, 0, 61),
#  (371, 375, 60),
#  (79, 372, 59),
#  (50, 10, 58),
#  (380, 374, 55),
#  (152, 0, 54),
#  (153, 0, 54),
#  (6, 3, 53),
#  (371, 374, 51),
#  (96, 71, 50),
#  (558, 3, 50),
#  (558, 374, 49),
#  (0, 3, 47),
#  (0, 10, 46),
#  (318, 91, 46),
#  (24, 3, 44),
#  (70, 72, 44),
#  (99, 372, 43),
#  (371, 243, 43),
#  (26, 374, 42),
#  (2, 372, 41),
#  (10, 243, 41),
#  (79, 2, 41),
#  (380, 317, 41),
#  (0, 558, 40),
#  (8, 372, 40),
#  (10, 371, 40),
#  (145, 0, 40),
#  (147, 0, 40),
#  (372, 379, 38),
#  (566, 372, 38),
#  (8, 2, 37),
#  (26, 3, 37),
#  (111, 0, 37),
#  (240, 374, 37),
#  (371, 6, 36),
#  (2, 3, 35),
#  (2, 374, 35),
#  (6, 375, 35),
#  (10, 376, 35),
#  (0, 310, 34),
#  (24, 374, 34),
td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.453966</td>
#       <td>0.315551</td>
#       <td>0.092660</td>
#       <td>08:02</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.464105</td>
#       <td>0.314495</td>
#       <td>0.092673</td>
#       <td>07:53</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.save('~/stage-1.34.040201') # 400X400 images
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-84-37b794d25329> in <module>
# ----> 1 learn.save('~/stage-1.34.040201') # 400X400 images
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in save(self, file, return_path, with_opt)
#     246     def save(self, file:PathLikeOrBinaryStream=None, return_path:bool=False, with_opt:bool=True):
#     247         "Save model and optimizer state (if `with_opt`) with `file` to `self.model_dir`. `file` can be file-like (file or buffer)"
# --> 248         if is_pathlike(file): self._test_writeable_path()
#     249         if rank_distrib(): return # don't save if slave proc
#     250         target = self.path/self.model_dir/f'{file}.pth' if is_pathlike(file) else file
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in _test_writeable_path(self)
#     180             tmp_file = get_tmp_file(path)
#     181         except OSError as e:
# --> 182             raise Exception(f"{e}\nCan't write to '{path}', set `learn.model_dir` attribute in Learner to a full libpath path that is writable") from None
#     183         os.remove(tmp_file)
#     184
#
# Exception: [Errno 30] Read-only file system: '/home/manoj/Documents/data/data/iwildcam-2020/train/400X400/models/tmpofrsoud6'
# Can't write to '/home/manoj/Documents/data/data/iwildcam-2020/train/400X400/models', set `learn.model_dir` attribute in Learner to a full libpath path that is writable

# %%
learn.fit_one_cycle(10)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.454767</td>
#       <td>0.313987</td>
#       <td>0.092419</td>
#       <td>07:57</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.517499</td>
#       <td>0.333733</td>
#       <td>0.099074</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.526896</td>
#       <td>0.340045</td>
#       <td>0.100384</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.521127</td>
#       <td>0.334265</td>
#       <td>0.097363</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.489286</td>
#       <td>0.320176</td>
#       <td>0.094691</td>
#       <td>07:57</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.477531</td>
#       <td>0.302632</td>
#       <td>0.089960</td>
#       <td>07:53</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.456170</td>
#       <td>0.288943</td>
#       <td>0.085163</td>
#       <td>07:54</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.429164</td>
#       <td>0.280362</td>
#       <td>0.082704</td>
#       <td>08:01</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.410616</td>
#       <td>0.272306</td>
#       <td>0.080098</td>
#       <td>07:55</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.415900</td>
#       <td>0.271435</td>
#       <td>0.079764</td>
#       <td>07:56</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.439466</td>
#       <td>0.284855</td>
#       <td>0.083934</td>
#       <td>08:06</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.453433</td>
#       <td>0.304684</td>
#       <td>0.092499</td>
#       <td>08:08</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.437835</td>
#       <td>0.285298</td>
#       <td>0.084749</td>
#       <td>08:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.420893</td>
#       <td>0.268409</td>
#       <td>0.079470</td>
#       <td>08:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.395585</td>
#       <td>0.263405</td>
#       <td>0.077720</td>
#       <td>08:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot_losses()

# %%
learn.fit_one_cycle(20)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.404031</td>
#       <td>0.261217</td>
#       <td>0.076971</td>
#       <td>08:09</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.407075</td>
#       <td>0.260436</td>
#       <td>0.076864</td>
#       <td>08:05</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.413197</td>
#       <td>0.264843</td>
#       <td>0.078508</td>
#       <td>08:09</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0
td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.324272</td>
#       <td>0.208131</td>
#       <td>0.060882</td>
#       <td>08:13</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.332541</td>
#       <td>0.208315</td>
#       <td>0.060842</td>
#       <td>07:53</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.model_dir="/home/manoj/Documents/GitHub/IWildCam2020/models"

# %% [markdown]
# The training losses are still greater than validation losses

# %% [markdown]
# Much better! But can be better. Maybe the learning rate needs to be reduced!

# %%
##learn.save('stage-1.34.033111') # 200X200 images best so far 0.699
#learn.save('stage-1.34.040110') # 400X400 images 0.645
#learn.save('stage-1.34.040116') # 400X400 images
#learn.save('stage-1.34.040309') # 224*224 images 0.702 duplicate training
#learn.save('stage-1.34.040309') # 224*224 images 0.708 duplicate training
learn.save('stage-1.34.040314') # 224*224 images 0.671 duplicate training

# %%
learn.lr_find()
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='83' class='' max='1197', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       6.93% [83/1197 00:37<08:17 1.2545]
#     </div>
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.recorder.plot()

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(10, max_lr=slice(5e-3,5e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.702850</td>
#       <td>0.469584</td>
#       <td>0.135996</td>
#       <td>08:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.245639</td>
#       <td>0.881694</td>
#       <td>0.237810</td>
#       <td>08:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.407298</td>
#       <td>0.992587</td>
#       <td>0.250464</td>
#       <td>08:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.206350</td>
#       <td>0.929891</td>
#       <td>0.251427</td>
#       <td>08:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.084468</td>
#       <td>0.773130</td>
#       <td>0.209640</td>
#       <td>08:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.891205</td>
#       <td>0.576488</td>
#       <td>0.161814</td>
#       <td>08:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.730181</td>
#       <td>0.494865</td>
#       <td>0.141114</td>
#       <td>08:30</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.584342</td>
#       <td>0.394553</td>
#       <td>0.114963</td>
#       <td>08:25</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.499557</td>
#       <td>0.341366</td>
#       <td>0.099782</td>
#       <td>08:19</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.457568</td>
#       <td>0.328649</td>
#       <td>0.096669</td>
#       <td>08:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.fit_one_cycle(40, max_lr=slice(5e-3,5e-2))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.702850</td>
#       <td>0.469584</td>
#       <td>0.135996</td>
#       <td>08:03</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>1.245639</td>
#       <td>0.881694</td>
#       <td>0.237810</td>
#       <td>08:04</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.407298</td>
#       <td>0.992587</td>
#       <td>0.250464</td>
#       <td>08:02</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.206350</td>
#       <td>0.929891</td>
#       <td>0.251427</td>
#       <td>08:03</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.084468</td>
#       <td>0.773130</td>
#       <td>0.209640</td>
#       <td>08:03</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.891205</td>
#       <td>0.576488</td>
#       <td>0.161814</td>
#       <td>08:02</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.730181</td>
#       <td>0.494865</td>
#       <td>0.141114</td>
#       <td>08:30</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.584342</td>
#       <td>0.394553</td>
#       <td>0.114963</td>
#       <td>08:25</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.499557</td>
#       <td>0.341366</td>
#       <td>0.099782</td>
#       <td>08:19</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.457568</td>
#       <td>0.328649</td>
#       <td>0.096669</td>
#       <td>08:16</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(40, max_lr=slice(5e-3,5e-2))
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='34' class='' max='40', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       85.00% [34/40 4:32:36<48:06]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>error_rate</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.467425</td>
#       <td>0.323445</td>
#       <td>0.095412</td>
#       <td>08:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.478429</td>
#       <td>0.324568</td>
#       <td>0.094784</td>
#       <td>08:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/train.py in fit_one_cycle(learn, cyc_len, max_lr, moms, div_factor, pct_start, final_div, wd, callbacks, tot_epochs, start_epoch)
#      21     callbacks.append(OneCycleScheduler(learn, max_lr, moms=moms, div_factor=div_factor, pct_start=pct_start,
#      22                                        final_div=final_div, tot_epochs=tot_epochs, start_epoch=start_epoch))
# ---> 23     learn.fit(cyc_len, max_lr, wd=wd, callbacks=callbacks)
#      24
#      25 def fit_fc(learn:Learner, tot_epochs:int=1, lr:float=defaults.lr,  moms:Tuple[float,float]=(0.95,0.85), start_pct:float=0.72,
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(self, epochs, lr, wd, callbacks)
#     198         else: self.opt.lr,self.opt.wd = lr,wd
#     199         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(callbacks)
# --> 200         fit(epochs, self, metrics=self.metrics, callbacks=self.callbacks+callbacks)
#     201
#     202     def create_opt(self, lr:Floats, wd:Floats=0.)->None:
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in fit(epochs, learn, callbacks, metrics)
#      99             for xb,yb in progress_bar(learn.data.train_dl, parent=pbar):
#     100                 xb, yb = cb_handler.on_batch_begin(xb, yb)
# --> 101                 loss = loss_batch(learn.model, xb, yb, learn.loss_func, learn.opt, cb_handler)
#     102                 if cb_handler.on_batch_end(loss): break
#     103
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in loss_batch(model, xb, yb, loss_func, opt, cb_handler)
#      31
#      32     if opt is not None:
# ---> 33         loss,skip_bwd = cb_handler.on_backward_begin(loss)
#      34         if not skip_bwd:                     loss.backward()
#      35         if not cb_handler.on_backward_end(): opt.step()
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/callback.py in on_backward_begin(self, loss)
#     288     def on_backward_begin(self, loss:Tensor)->Tuple[Any,Any]:
#     289         "Handle gradient calculation on `loss`."
# --> 290         self.smoothener.add_value(loss.float().detach().cpu())
#     291         self.state_dict['last_loss'], self.state_dict['smooth_loss'] = loss, self.smoothener.smooth
#     292         self('backward_begin', call_mets=False)
#
# KeyboardInterrupt:

# %% [markdown]
# Maybe a few more fittings will make the losses better

# %%
learn.save('stage-1.50.040101')

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=90)

# %%
interp.plot_confusion_matrix(figsize=(12,12), dpi=90)

# %%
#jsonTestFilePath='/home/manoj/Documents/data/data/iwildcam-2020/iwildcam2020_test_information.json'
jsonTestFilePath=dataPath/'iwildcam2020_test_information.json'
testData = readJSONFile(jsonTestFilePath)

testImages=testData["images"]
testCategories = testData["categories"]
testInfo = testData["info"]

# Convert to Data frame

testImages = pd.DataFrame.from_dict(testImages)
testCategories = pd.DataFrame.from_dict(testCategories)

#Remove data from memory
del testData, testInfo

# Remove Unnecessary fields from images
testDf1 = pd.DataFrame(testImages.file_name)

# %%
testImages
# Out:
#        seq_num_frames  location                 datetime  \
# 0                   1        84  2013-08-02 21:44:00.000
# 1                   1        84  2013-08-02 21:51:00.000
# 2                   1       548  2013-04-25 18:23:00.000
# 3                   1       181  2013-04-17 16:10:00.000
# 4                   1       181  2013-04-20 03:11:00.000
# ...               ...       ...                      ...
# 62889              -1         5  2013-08-01 18:45:20.000
# 62890              -1         5  2013-08-01 18:45:21.000
# 62891              -1         5  2013-08-01 18:45:22.000
# 62892              -1         5  2013-08-01 18:45:22.000
# 62893              -1         5  2013-08-01 18:45:23.000
#
#                                          id  frame_num  \
# 0      88037cce-21bc-11ea-a13a-137349068a90          1
# 1      963e6b46-21bc-11ea-a13a-137349068a90          1
# 2      8a1b53ba-21bc-11ea-a13a-137349068a90          1
# 3      938c0d5e-21bc-11ea-a13a-137349068a90          1
# 4      95b9bd92-21bc-11ea-a13a-137349068a90          1
# ...                                     ...        ...
# 62889  978d4224-21bc-11ea-a13a-137349068a90         -1
# 62890  8bd8cad4-21bc-11ea-a13a-137349068a90         -1
# 62891  8c894fc6-21bc-11ea-a13a-137349068a90         -1
# 62892  97bffbf6-21bc-11ea-a13a-137349068a90         -1
# 62893  91d4fb7e-21bc-11ea-a13a-137349068a90         -1
#
#                                      seq_id  width  height  \
# 0      88037e90-21bc-11ea-a13a-137349068a90   2771    1779
# 1      963e6cb8-21bc-11ea-a13a-137349068a90   2771    1779
# 2      8a1b5554-21bc-11ea-a13a-137349068a90   2895    1865
# 3      938c0f02-21bc-11ea-a13a-137349068a90   2902    1818
# 4      95b9be96-21bc-11ea-a13a-137349068a90   2212    1841
# ...                                     ...    ...     ...
# 62889  995a6da2-21bc-11ea-a13a-137349068a90   1280    1024
# 62890  995a6da2-21bc-11ea-a13a-137349068a90   1280    1024
# 62891  995a6da2-21bc-11ea-a13a-137349068a90   1280    1024
# 62892  995a6da2-21bc-11ea-a13a-137349068a90   1280    1024
# 62893  995a6da2-21bc-11ea-a13a-137349068a90   1280    1024
#
#                                       file_name
# 0      88037cce-21bc-11ea-a13a-137349068a90.jpg
# 1      963e6b46-21bc-11ea-a13a-137349068a90.jpg
# 2      8a1b53ba-21bc-11ea-a13a-137349068a90.jpg
# 3      938c0d5e-21bc-11ea-a13a-137349068a90.jpg
# 4      95b9bd92-21bc-11ea-a13a-137349068a90.jpg
# ...                                         ...
# 62889  978d4224-21bc-11ea-a13a-137349068a90.jpg
# 62890  8bd8cad4-21bc-11ea-a13a-137349068a90.jpg
# 62891  8c894fc6-21bc-11ea-a13a-137349068a90.jpg
# 62892  97bffbf6-21bc-11ea-a13a-137349068a90.jpg
# 62893  91d4fb7e-21bc-11ea-a13a-137349068a90.jpg
#
# [62894 rows x 9 columns]

# %%
#testPath=Path("/home/manoj/Documents/data/data/iwildcam-2020/test/100X100")
testPath=dataPath/'test/400X400'

# %%
testPath.ls()[10]
# Out:
# PosixPath('/home/manoj/Documents/data/data/iwildcam-2020/test/400X400/86769580-21bc-11ea-a13a-137349068a90.jpg')

# %%
for i, file in enumerate(testPath.ls()):
    if (i < 10) :
        print(file)
# Out:
# /home/manoj/Documents/data/data/iwildcam-2020/test/400X400/867611a0-21bc-11ea-a13a-137349068a90.jpg
# /home/manoj/Documents/data/data/iwildcam-2020/test/400X400/86761d58-21bc-11ea-a13a-137349068a90.jpg
# /home/manoj/Documents/data/data/iwildcam-2020/test/400X400/867624e2-21bc-11ea-a13a-137349068a90.jpg
# /home/manoj/Documents/data/data/iwildcam-2020/test/400X400/86762942-21bc-11ea-a13a-137349068a90.jpg
# /home/manoj/Documents/data/data/iwildcam-2020/test/400X400/86763c0c-21bc-11ea-a13a-137349068a90.jpg
# /home/manoj/Documents/data/data/iwildcam-2020/test/400X400/86765afc-21bc-11ea-a13a-137349068a90.jpg
# /home/manoj/Documents/data/data/iwildcam-2020/test/400X400/867665c4-21bc-11ea-a13a-137349068a90.jpg
# /home/manoj/Documents/data/data/iwildcam-2020/test/400X400/86767820-21bc-11ea-a13a-137349068a90.jpg
# /home/manoj/Documents/data/data/iwildcam-2020/test/400X400/86768504-21bc-11ea-a13a-137349068a90.jpg
# /home/manoj/Documents/data/data/iwildcam-2020/test/400X400/8676929c-21bc-11ea-a13a-137349068a90.jpg

# %%
learn.predict(open_image(testPath.ls()[1]), True)[1]
# Out:
# Category 0

# %%
for i, file in enumerate(testPath.ls()):
    if (i < 10) :
        print(learn.predict(open_image(testPath.ls()[i]))[0])
# Out:
# 0
# 0
# 240
# 0
# 558
# 372
# 111
# 99
# 0
# 115

# %%
i=0
for file in testPath.ls():
    if (i < 10) :
        print(learn.predict(open_image(file))[0])
        i=i+1
# Out:
# 0
# 0
# 240
# 0
# 558
# 372
# 111
# 99
# 0
# 115

# %%
#df=[ {"file_name":str(file).replace(str(testPath)+'/',''), "name": learn.predict(open_image(file))[0] }
df=[ {"file_name":str(file).replace(str(testPath)+'/',''), "Id": learn.predict(open_image(file))[0] }
    for file in testPath.ls()[:]
]

# %%
df=pd.DataFrame(df)

# %%
df
# Out:
#                                       file_name   Id
# 0      867611a0-21bc-11ea-a13a-137349068a90.jpg    0
# 1      86761d58-21bc-11ea-a13a-137349068a90.jpg  258
# 2      867624e2-21bc-11ea-a13a-137349068a90.jpg  371
# 3      86762942-21bc-11ea-a13a-137349068a90.jpg    0
# 4      86763c0c-21bc-11ea-a13a-137349068a90.jpg  558
# ...                                         ...  ...
# 62890  995a286a-21bc-11ea-a13a-137349068a90.jpg    0
# 62891  995a3fda-21bc-11ea-a13a-137349068a90.jpg    0
# 62892  995a4dfe-21bc-11ea-a13a-137349068a90.jpg  558
# 62893  995a548e-21bc-11ea-a13a-137349068a90.jpg  372
# 62894  995a6208-21bc-11ea-a13a-137349068a90.jpg  347
#
# [62895 rows x 2 columns]

# %%
dforg=df

# %%
#os.path.basename(df["file_name"][0])

df["file_name"]=list(map(lambda x: os.path.basename(x), df["file_name"]))

# %%
#jsonSubmissionFilePath='/home/manoj/Documents/data/data/iwildcam-2020/sample_submission.csv'
jsonSubmissionFilePath=dataPath/'sample_submission.csv'
submission=pd.read_csv(jsonSubmissionFilePath)

# %%
submission.drop(columns=["Category"], inplace=True)
submission
# Out:
#                                          Id
# 0      873ff218-21bc-11ea-a13a-137349068a90
# 1      884103be-21bc-11ea-a13a-137349068a90
# 2      973feb64-21bc-11ea-a13a-137349068a90
# 3      8ebf4e44-21bc-11ea-a13a-137349068a90
# 4      95a33464-21bc-11ea-a13a-137349068a90
# ...                                     ...
# 62865  976c0b90-21bc-11ea-a13a-137349068a90
# 62866  92f567fa-21bc-11ea-a13a-137349068a90
# 62867  9692fb2a-21bc-11ea-a13a-137349068a90
# 62868  8b0412f8-21bc-11ea-a13a-137349068a90
# 62869  8d37bc78-21bc-11ea-a13a-137349068a90
#
# [62870 rows x 1 columns]

# %%
testXref=testImages[["file_name","id"]]

# %%
len(testXref)
# Out:
# 62894

# %%
#testXref.groupby('file_name').first()
df.merge(testXref, on='file_name')
# Out:
#                                       file_name   Id  \
# 0      867611a0-21bc-11ea-a13a-137349068a90.jpg    0
# 1      86761d58-21bc-11ea-a13a-137349068a90.jpg  258
# 2      867624e2-21bc-11ea-a13a-137349068a90.jpg  371
# 3      86762942-21bc-11ea-a13a-137349068a90.jpg    0
# 4      86763c0c-21bc-11ea-a13a-137349068a90.jpg  558
# ...                                         ...  ...
# 62889  995a286a-21bc-11ea-a13a-137349068a90.jpg    0
# 62890  995a3fda-21bc-11ea-a13a-137349068a90.jpg    0
# 62891  995a4dfe-21bc-11ea-a13a-137349068a90.jpg  558
# 62892  995a548e-21bc-11ea-a13a-137349068a90.jpg  372
# 62893  995a6208-21bc-11ea-a13a-137349068a90.jpg  347
#
#                                          id
# 0      867611a0-21bc-11ea-a13a-137349068a90
# 1      86761d58-21bc-11ea-a13a-137349068a90
# 2      867624e2-21bc-11ea-a13a-137349068a90
# 3      86762942-21bc-11ea-a13a-137349068a90
# 4      86763c0c-21bc-11ea-a13a-137349068a90
# ...                                     ...
# 62889  995a286a-21bc-11ea-a13a-137349068a90
# 62890  995a3fda-21bc-11ea-a13a-137349068a90
# 62891  995a4dfe-21bc-11ea-a13a-137349068a90
# 62892  995a548e-21bc-11ea-a13a-137349068a90
# 62893  995a6208-21bc-11ea-a13a-137349068a90
#
# [62894 rows x 3 columns]

# %%
#df1=df.merge(testImages, on='file_name')[["id","name"]]
df1=df.merge(testXref, on='file_name')[["id","Id"]]
#df1=df1.rename(columns={"id":"Id"})
df1=df1.rename(columns={"Id":"Category", "id":"Id"})

# %%
df1
# Out:
#                                          Id Category
# 0      867611a0-21bc-11ea-a13a-137349068a90        0
# 1      86761d58-21bc-11ea-a13a-137349068a90      258
# 2      867624e2-21bc-11ea-a13a-137349068a90      371
# 3      86762942-21bc-11ea-a13a-137349068a90        0
# 4      86763c0c-21bc-11ea-a13a-137349068a90      558
# ...                                     ...      ...
# 62889  995a286a-21bc-11ea-a13a-137349068a90        0
# 62890  995a3fda-21bc-11ea-a13a-137349068a90        0
# 62891  995a4dfe-21bc-11ea-a13a-137349068a90      558
# 62892  995a548e-21bc-11ea-a13a-137349068a90      372
# 62893  995a6208-21bc-11ea-a13a-137349068a90      347
#
# [62894 rows x 2 columns]

# %%
#df2=submission.merge(df1, on="Id")[["Id","Category"]]
df2=submission.merge(df1, on="Id")

# %%
df2
# Out:
#                                          Id Category
# 0      873ff218-21bc-11ea-a13a-137349068a90        0
# 1      884103be-21bc-11ea-a13a-137349068a90       96
# 2      973feb64-21bc-11ea-a13a-137349068a90        3
# 3      8ebf4e44-21bc-11ea-a13a-137349068a90       10
# 4      95a33464-21bc-11ea-a13a-137349068a90       10
# ...                                     ...      ...
# 62865  976c0b90-21bc-11ea-a13a-137349068a90      374
# 62866  92f567fa-21bc-11ea-a13a-137349068a90       10
# 62867  9692fb2a-21bc-11ea-a13a-137349068a90        0
# 62868  8b0412f8-21bc-11ea-a13a-137349068a90        0
# 62869  8d37bc78-21bc-11ea-a13a-137349068a90      371
#
# [62870 rows x 2 columns]

# %%
#df["file_name"]

# %%
df2.to_csv("submission.2020040314.csv", index=False)

# %%
preds, y, losses = learn.get_preds(ds_type=DatasetType.Test, with_loss=True)
#y = torch.argmax(preds, dim=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-146-d7d0fc553902> in <module>
# ----> 1 preds, y, losses = learn.get_preds(ds_type=DatasetType.Test, with_loss=True)
#       2 #y = torch.argmax(preds, dim=1)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in get_preds(self, ds_type, activ, with_loss, n_batch, pbar)
#     339         callbacks = [cb(self) for cb in self.callback_fns + listify(defaults.extra_callback_fns)] + listify(self.callbacks)
#     340         return get_preds(self.model, self.dl(ds_type), cb_handler=CallbackHandler(callbacks),
# --> 341                          activ=activ, loss_func=lf, n_batch=n_batch, pbar=pbar)
#     342
#     343     def pred_batch(self, ds_type:DatasetType=DatasetType.Valid, batch:Tuple=None, reconstruct:bool=False,
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in get_preds(model, dl, pbar, cb_handler, activ, loss_func, n_batch)
#      42     "Tuple of predictions and targets, and optional losses (if `loss_func`) using `dl`, max batches `n_batch`."
#      43     res = [to_float(torch.cat(o).cpu()) for o in
# ---> 44            zip(*validate(model, dl, cb_handler=cb_handler, pbar=pbar, average=False, n_batch=n_batch))]
#      45     if loss_func is not None:
#      46         with NoneReduceOnCPU(loss_func) as lf: res.append(lf(res[0], res[1]))
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/basic_train.py in validate(model, dl, loss_func, cb_handler, pbar, average, n_batch)
#      54     with torch.no_grad():
#      55         val_losses,nums = [],[]
# ---> 56         if cb_handler: cb_handler.set_dl(dl)
#      57         for xb,yb in progress_bar(dl, parent=pbar, leave=(pbar is not None)):
#      58             if cb_handler: xb, yb = cb_handler.on_batch_begin(xb, yb, train=False)
#
# ~/anaconda3/envs/fastai/lib/python3.6/site-packages/fastai/callback.py in set_dl(self, dl)
#     254         "Set the current `dl` used."
#     255         if hasattr(self, 'cb_dl'): self.callbacks.remove(self.cb_dl)
# --> 256         if isinstance(dl.dataset, Callback):
#     257             self.callbacks.append(dl.dataset)
#     258             self.cb_dl = dl.dataset
#
# AttributeError: 'NoneType' object has no attribute 'dataset'

# %%
# !pwd

# %%
learn1 = cnn_learner(data, models.resnet34, metrics=error_rate)
